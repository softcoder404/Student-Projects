# %%
import pandas as pd

# %%
data2 = pd.read_csv('/Users/mac/Documents/dataset.csv',header=0, index_col=0)

# %%
data2.head(9)
# Out:
#       Day1  Day2  Day3  Day4  Day5  Day6  Day7  Day8  Day9  Day10
# TIME
# 1       24  25.0    27    25   8.0    32    24    25    26   27.0
# 2       23  25.0    24    24   8.0    18    23    26    17   26.0
# 3       23  25.0    23    22   8.0    12    23    26    16   25.0
# 4       23   2.4    23    29   8.0    12    23    26    16   25.0
# 5       20   3.0    18    31   9.2    12    20    27    17   27.0
# 6       19  15.0    30    26  15.0    14    19    27    20   31.0
# 7       19   9.9    20    36  10.0    17    19    21    26   34.0
# 8       23  13.0    19    26  15.0    18    23    21    22   29.0
# 9       23  15.0    23    29  12.0    17    23    22    30   27.0

# %%
import seaborn as sb

# %%
sb.pairplot(data2)
